# %% [markdown]
# # File Handling

# %% [markdown]
# ### Python supports a wide range of file formats. Here are some common examples:
#
# #### `Text files:`
#
# Plain text files (.txt).
#
# CSV files (.csv).
#
# JSON files (.json).
#
# XML files (.xml).
#
# HTML files (.html).
#
#
# `Binary files:`
#
# Images: (.jpg,.png,.gif,.bmp,.tiff)
#
# Audio files (.mp3,.wav,.FLAC)
#
# Video files (.mp4,.avi,.mkv).
#
# PDF files (.pdf).
#
# Excel files (.xls,.xlsx).
#
# Word documents (.doc,.docx).
#
# Compressed files (.zip,.tar,.gz).
#
#
# #### `Specialised formats:`
#
# SQLite Databases (.sqlite,.db).
#
# HDF5 files (.h5).
#
# Pickle Files (.pkl)
#
# YAML files (.yaml,.yml).
#
#
# #### `Python-Specific Files:`
#
# Python source code (.py).
#
# Python Compiled Files (.pyc).
#
# Jupyter Notebook (.ipynb)

# %% [markdown]
# #### Python is versatile and can handle many types of files, the most fundamental ones are text and binary files
#
# ###### Text files are files that contain plain text and can be read and written with the open function, which has modes like 'r' for reading and 'w' for writing. Example file extensions:.txt,.csv, and.json.
#
# ###### Binary files contain binary data and can be read and written using the open function, but in different modes, such as 'rb' for reading binary and 'wb' for writing binary. For example: Images (.jpg,.png) and audio files (.mp3,.wav).).

# %% [markdown]
# # File vs File Object

# %% [markdown]
# ### File
# A file is a document or a piece of information that can be created, modified and stored by a user or an operating system.
#
# In Python, a file can be either text or binary. In this course, we will only work with text files.
#
# Breast_Cancer.csv
#
# ### File Object
# A file object is a python object that holds data imported from a file. To use a file in our program, we first need to import it and convert it into a file object. Once it is a file object, we can modify it as needed. This object contains methods and properties for dealing with the file, including reading from, writing to, and closing it.
#
# file_path = 'C:/Users/user/Desktop/Breast_Cancer.csv'

# %% [markdown]
# # Reading and Parsing

# %% [markdown]
# ### Reading
# Reading is the process of obtaining and retrieving the contents of a file.
# ### Parsing
#
# Parsing often entails analysing the structure of the file's content and extracting important data into an organised format, such as lists, dictionaries, or data frames.
#
#
# Reading a file entails examining its contents. Think of it as opening a book and reading the words on the pages.
#
# Parsing is the process of making sense of information read from a file. It's similar to discovering the chapters and parts of a book and comprehending its structur
#
# When you parse a file, you understand its contents to extract the most significant information.

# %% [markdown]
# # Data Structures

# %% [markdown]
# #### Data structures are methods of organising and storing data to be easily accessed and used. They determine the efficiency with which data is processed and stored. Data structures may increase speed, minimise resource use, and make code more readable and maintainable.

# %% [markdown]
# ### Structured Data

# %% [markdown]
# Structured data refers to information that is organized in a way that makes finding specific pieces of information easy. This type of data is often in a tabular form, such as an Excel spreadsheet or SQL database. It can also be stored in databases and managed from one computer.

# %% [markdown]
# ### Unstructured Data

# %% [markdown]
# Unstructured data refers to information that is not organized in a way that makes finding specific pieces of information easy. This type of data can include video, audio, photos, presentations, web pages, text, and more.

# %% [markdown]
# ### Semi-Structured Data

# %% [markdown]
# Semi-structured data refers to a middle ground between structured and unstructured data. Semi-structured data does not have a rigid structure like structured data, but it still has some organizational properties, such as tags or markers to separate data elements. This type of data is more about using different patterns for storing and organizing the data in a way that makes it easier to access and analyze.
#
# Examples:
#
# JSON (JavaScript Object Notation),
#
# XML (eXtensible Markup Language)
#
# HTML (HyperText Markup Language)

# %% [markdown]
# ### Let's Look at a dataset from Kaggle

# %%
file_path = 'C:/Users/user/Desktop/Breast_Cancer.csv'

# %%
with open(file_path, 'r') as breast_cancer_data:
    data = breast_cancer_data.read()

# %%
print(data)
# Out:
# Age,Race,Marital Status,T Stage ,N Stage,6th Stage,differentiate,Grade,A Stage,Tumor Size,Estrogen Status,Progesterone Status,Regional Node Examined,Reginol Node Positive,Survival Months,Status
# 68,White,Married,T1,N1,IIA,Poorly differentiated,3,Regional,4,Positive,Positive,24,1,60,Alive
# 50,White,Married,T2,N2,IIIA,Moderately differentiated,2,Regional,35,Positive,Positive,14,5,62,Alive
# 58,White,Divorced,T3,N3,IIIC,Moderately differentiated,2,Regional,63,Positive,Positive,14,7,75,Alive
# 58,White,Married,T1,N1,IIA,Poorly differentiated,3,Regional,18,Positive,Positive,2,1,84,Alive
# 47,White,Married,T2,N1,IIB,Poorly differentiated,3,Regional,41,Positive,Positive,3,1,50,Alive
# 51,White,Single ,T1,N1,IIA,Moderately differentiated,2,Regional,20,Positive,Positive,18,2,89,Alive
# 51,White,Married,T1,N1,IIA,Well differentiated,1,Regional,8,Positive,Positive,11,1,54,Alive
# 40,White,Married,T2,N1,IIB,Moderately differentiated,2,Regional,30,Positive,Positive,9,1,14,Dead
# ...

# %% [markdown]
# ### Using the csv modulue

# %%
import csv

file_path = 'C:/Users/user/Desktop/Breast_Cancer.csv'

with open(file_path, 'r') as breast_cancer_data:
    csv_reader = csv.reader(breast_cancer_data)
    
 
    for row in csv_reader:
        print(row)
# Out:
# ['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage', 'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status', 'Progesterone Status', 'Regional Node Examined', 'Reginol Node Positive', 'Survival Months', 'Status']
# ['68', 'White', 'Married', 'T1', 'N1', 'IIA', 'Poorly differentiated', '3', 'Regional', '4', 'Positive', 'Positive', '24', '1', '60', 'Alive']
# ['50', 'White', 'Married', 'T2', 'N2', 'IIIA', 'Moderately differentiated', '2', 'Regional', '35', 'Positive', 'Positive', '14', '5', '62', 'Alive']
# ['58', 'White', 'Divorced', 'T3', 'N3', 'IIIC', 'Moderately differentiated', '2', 'Regional', '63', 'Positive', 'Positive', '14', '7', '75', 'Alive']
# ['58', 'White', 'Married', 'T1', 'N1', 'IIA', 'Poorly differentiated', '3', 'Regional', '18', 'Positive', 'Positive', '2', '1', '84', 'Alive']
# ['47', 'White', 'Married', 'T2', 'N1', 'IIB', 'Poorly differentiated', '3', 'Regional', '41', 'Positive', 'Positive', '3', '1', '50', 'Alive']
# ...

# %% [markdown]
# #### Using Numpy to import the data

# %%
import numpy as np

file_path = 'C:/Users/user/Desktop/Breast_Cancer.csv'

# %%
dataset = np.genfromtxt(file_path, delimiter=',')
print(dataset)
# Out:
# [[ nan  nan  nan ...  nan  nan  nan]
#  [ 68.  nan  nan ...   1.  60.  nan]
#  [ 50.  nan  nan ...   5.  62.  nan]
#  ...
#  [ 68.  nan  nan ...   3.  69.  nan]
#  [ 58.  nan  nan ...   1.  72.  nan]
#  [ 46.  nan  nan ...   2. 100.  nan]]

# %%
head = dataset[:5]
print(head)
# Out:
# [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [68. nan nan nan nan nan nan  3. nan  4. nan nan 24.  1. 60. nan]
#  [50. nan nan nan nan nan nan  2. nan 35. nan nan 14.  5. 62. nan]
#  [58. nan nan nan nan nan nan  2. nan 63. nan nan 14.  7. 75. nan]
#  [58. nan nan nan nan nan nan  3. nan 18. nan nan  2.  1. 84. nan]]

# %% [markdown]
# ## Using Pandas

# %%
import pandas as pd

file_path = 'C:/Users/user/Desktop/Breast_Cancer.csv'

df = pd.read_csv(file_path)

print(df.head())
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %%
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %% [markdown]
# ### Let's import directly from Kaggle

# %%
pip install Kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from zipfile import ZipFile

# %%
# !kaggle datasets download -d zynicide/wine-reviews
# Out:
# 2024-07-14 23:02:11,828 WARNING Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001FFC72CF4D0>, 'Connection to www.kaggle.com timed out. (connect timeout=None)')': /api/v1/datasets/metadata/zynicide/wine-reviews
# 2024-07-14 23:02:32,879 WARNING Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001FFC72CFC10>, 'Connection to www.kaggle.com timed out. (connect timeout=None)')': /api/v1/datasets/metadata/zynicide/wine-reviews
# ...

# %%
# Extracting the downloaded zip file
with ZipFile('C:/Users/user/Desktop/New folder/Gomycode/wine-reviews.zip', 'r') as zip_ref:
    zip_ref.extractall('wine-reviews')

# %%
# Load the data using pandas or any other library
import pandas as pd
data = pd.read_csv('C:/Users/user/Desktop/New folder/Gomycode/wine-reviews/winemag-data_first150k.csv')

# %%
print(data)
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
print(data.head())
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %% [markdown]
# # Data Cleaning and Transformation

# %% [markdown]
# ### Data Preprocessing
#
# PANDAS is a popular Python library used for data manipulation and analysis. It features two main data structures: the "series" object, representing a single column of data or observations related to a single variable, and the "data frame" object, which contains multiple columns of data.
#
# ![image.png](attachment:f05079dd-f85f-4309-aeed-6c15c042cc10.png)

# %%
# installing pandas
# !pip install pandas

# %%
import pandas as pd

# %%
products = ['A', 'B', 'C', 'D']

# %%
type(products)
# Out:
# list

# %%
# convert the list into a pandas Series using the pd.Series() function.

product_categories = pd.Series(products)
print(product_categories)
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %%
type(product_categories)
# Out:
# pandas.core.series.Series

# %%
daily_rates_dollars = pd.Series([40, 45, 50, 60])
print(daily_rates_dollars)
# Out:
# 0    40
# 1    45
# 2    50
# 3    60
# dtype: int64

# %%
# creating a pandas Series from a numpy array using the pd.Series()
import numpy as np

# %%
array_a = np.array([10, 20, 30, 40, 50])
type(array_a)
# Out:
# numpy.ndarray

# %%
series_a = pd.Series(array_a)

# %%
print(series_a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32

# %%
type(series_a)
# Out:
# pandas.core.series.Series

# %%
# create a Series using our own indexes
import pandas as pd
color=["pink", "white", "black", "blue"]
occurence = [20, 15, 6, 43]
S=pd.Series(occurence, index=color)
print(S)
# Out:
# pink     20
# white    15
# black     6
# blue     43
# dtype: int64

# %% [markdown]
# #### Series addition

# %%
import pandas as pd
color=["pink", "white", "black", "blue"]
S1=pd.Series([20, 15, 6, 43], index=color)
S2=pd.Series([3, 22, 9, 10], index=color)
print(S1+S2)
# Out:
# pink     23
# white    37
# black    15
# blue     53
# dtype: int64

# %% [markdown]
# # Pandas DataFrames
#
# A Data Frame is a 2-dimensional labeled data structure with columns of potentially different types.
#
# ![image.png](attachment:c027b9e1-e662-4a3f-b6bb-2de19e242f46.png)

# %% [markdown]
# ### Creating Data Frames from Scratch in Python

# %%
data = {"ProductName": ["Product 1", "Product 2", "Product 3"], "ProductPrice": [10, 20, 30]}
df1 = pd.DataFrame(data)
print(df1)
# Out:
#   ProductName  ProductPrice
# 0   Product 1            10
# 1   Product 2            20
# 2   Product 3            30

# %% [markdown]
# #### Construct a DataFrame from a dictionary of lists + specify an index

# %%
data = {"ProductName": ["Product 1", "Product 2", "Product 3"], "ProductPrice": [10, 20, 30]}
df2 = pd.DataFrame(data, index=['A', 'B', 'C'])

# %%
print(df2)
# Out:
#   ProductName  ProductPrice
# A   Product 1            10
# B   Product 2            20
# C   Product 3            30

# %%
# Constructing a DataFrame from a list of dictionaries
data = [{"ProductName": "Product 1", "ProductPrice": 10}, 
        {"ProductName": "Product 2", "ProductPrice": 20}, 
        {"ProductName": "Product 3", "ProductPrice": 30}]

# %%
df3 = pd.DataFrame(data)
print(df3)
# Out:
#   ProductName  ProductPrice
# 0   Product 1            10
# 1   Product 2            20
# 2   Product 3            30

# %%
### Constructing a DataFrame from a dictionary of pandas Series
product_name = pd.Series(["Product 1", "Product 2", "Product 3"])
product_price = pd.Series([10, 20, 30])
data = {"ProductName": product_name, "ProductPrice": product_price}
df4 = pd.DataFrame(data)
print(df4)
# Out:
#   ProductName  ProductPrice
# 0   Product 1            10
# 1   Product 2            20
# 2   Product 3            30

# %%
### Constructing a DataFrame from a list of lists
data = [['Product 1', 10], ['Product 2', 20], ['Product 3', 30]]
df5 = pd.DataFrame(data, columns=['ProductName', 'ProductPrice'])
print(df5)
# Out:
#   ProductName  ProductPrice
# 0   Product 1            10
# 1   Product 2            20
# 2   Product 3            30

# %%
### Constructing a DataFrame in a Professional Way
data = {'ProductName': ['Product 1', 'Product 2', 'Product 3'], 'ProductPrice': [10, 20, 30]}
index = ['A', 'B', 'C']
df6 = pd.DataFrame(data, index=index)
print(df6)
# Out:
#   ProductName  ProductPrice
# A   Product 1            10
# B   Product 2            20
# C   Product 3            30

# %% [markdown]
# # Programming puzzle.
#
# ### Instructions :
#
# Create a list of products, 'Apple', 'Banana', 'Carrot', 'Daikon'.
#
# Convert the list into a pandas Series using the pd.Series() function.
#
# Print out the new Series to see the values.
#
# Create a Series with prices of the products, [2, 1, 3, 4]
#
# Print out the new Series to see the values.
#
# Add the two Series together and print out the result.
#
# Create a DataFrame using a dictionary of lists, where the keys are 'Product' and 'Price' and the values are the two Series you created.
#
# Print out the DataFrame to see the values.
#
# Create a DataFrame using a list of dictionaries, where each dictionary represents a row in the DataFrame with keys 'Product' and 'Price' and values from the two Series you created.
#
# Print out the DataFrame to see the values.
#
# Make sure to import pandas library before doing the exercises.

# %%
import pandas as pd

products = ['Apple', 'Banana', 'Carrot', 'Daikon']

series_products = pd.Series(products)
print("\n Products Series:\n", series_products)
# Out:
#  Products Series:
#  0     Apple
# 1    Banana
# 2    Carrot
# 3    Daikon
# dtype: object

# %%
prices = [2, 1, 3, 4]
series_prices = pd.Series(prices)
print("Prices Series:")
print(series_prices)
# Out:
# Prices Series:
# 0    2
# 1    1
# 2    3
# 3    4
# dtype: int64

# %%
Series_sum = series_products+ " " + series_prices.astype(str)
print(Series_sum)
# Out:
# 0     Apple 2
# 1    Banana 1
# 2    Carrot 3
# 3    Daikon 4
# dtype: object

# %%
## creating a DataFrame using a dictionary of lists
dict_ = {
    'Product': series_products,
    'Price': series_prices
}

# %%
data_frame = pd.DataFrame(dict_)
print("\n A DataFrame from dictionary of lists:\n", data_frame)
# Out:
#  A DataFrame from dictionary of lists:
#    Product  Price
# 0   Apple      2
# 1  Banana      1
# 2  Carrot      3
# 3  Daikon      4

# %%
# A DataFrame using a list of dictionaries
data_list = [
    {'Product': product, 'Price': price}
    for product, price in zip(products, prices)
]
df_from_list = pd.DataFrame(data_list)
print("\nA DataFrame from list of dictionaries:\n", df_from_list)
# Out:
# A DataFrame from list of dictionaries:
#    Product  Price
# 0   Apple      2
# 1  Banana      1
# 2  Carrot      3
# 3  Daikon      4

# %% [markdown]
# # Dataframe Bracket Selection
# # We can select specific rows or columns from our DataFrame

# %% [markdown]
# ### iloc
# ## The iloc indexing method selects rows and columns depending on their integer position.
#
# ## Syntax: df.iloc[row_index, column_index].
#
# ## df.iloc[0] selects the first row.
#
# ## df.iloc[:, 1] selects the second column.
#
# ## df.iloc[1:3, 0:2]: Returns a subset of rows and columns (second and third rows, first and second columns).).

# %% [markdown]
# # loc
#
# ## loc is used for label-based indexing, which means you may choose rows and columns based on their labels (names).
#
# ## Syntax is: df.loc[row_label, column_label].
#
# ## Example: df.loc['row_label']: This selects the row with the supplied label.
#
# ## df.loc[:, 'column_label']: This returns the column with the given label.
#
# ## df.loc['row_label1':'row_label2', 'column_label1':'column_label2']: This returns a subset of rows and columns based on labels

# %%
import pandas as pd

data = {
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8],
    'C': [9, 10, 11, 12],
    'D': [13, 14, 15, 16]
}
names_ = pd.DataFrame(data, index=["Jack", "Thomas", "Alexandre", "Anne"])
print("Data Frame")
print(names_)
# Out:
# Data Frame
#            A  B   C   D
# Jack       1  5   9  13
# Thomas     2  6  10  14
# Alexandre  3  7  11  15
# Anne       4  8  12  16

# %%
# Let's use loc to select the first and second rows
rows_ = names_.loc[["Jack", "Thomas"]]
print(rows_)
# Out:
#         A  B   C   D
# Jack    1  5   9  13
# Thomas  2  6  10  14

# %%
# let's use iloc to select the second and third columns for all rows
columns_ = names_.iloc[:, 1:3]
print(columns_)
# Out:
#            B   C
# Jack       5   9
# Thomas     6  10
# Alexandre  7  11
# Anne       8  12

# %%
# let's use loc to select specific columns for all rows
columns_loc = names_.loc[:, ['B', 'C']]
print(columns_loc)
# Out:
#            B   C
# Jack       5   9
# Thomas     6  10
# Alexandre  7  11
# Anne       8  12

# %%
# let's use iloc to select specific rows
# selecting the first and second rows
rows_iloc = names_.iloc[0:2] 
print(rows_iloc)
# Out:
#         A  B   C   D
# Jack    1  5   9  13
# Thomas  2  6  10  14

# %%
# let use iloc to select all columns for specific rows 
# Selecting first and third rows
_rows = names_.iloc[[0, 2]]
print(_rows)
# Out:
#            A  B   C   D
# Jack       1  5   9  13
# Alexandre  3  7  11  15

# %% [markdown]
# # Let's look at our imported dataset

# %%
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %% [markdown]
# ### Using iloc and loc on the dataset columns

# %%
# for example, we want to focus on the first five columns
first_5 = df.iloc[:, :5]
print(first_5)
# Out:
#       Age   Race Marital Status T Stage  N Stage
# 0      68  White        Married       T1      N1
# 1      50  White        Married       T2      N2
# 2      58  White       Divorced       T3      N3
# 3      58  White        Married       T1      N1
# 4      47  White        Married       T2      N1
# ...   ...    ...            ...      ...     ...
# 4019   62  Other        Married       T1      N1
# 4020   56  White       Divorced       T2      N2
# 4021   68  White        Married       T2      N1
# 4022   58  Black       Divorced       T2      N1
# 4023   46  White        Married       T2      N1
#
# [4024 rows x 5 columns]

# %%
# let's use loc to select specific columns for all rows
cancer_specific = df.loc[:, ['Tumor Size', 'Estrogen Status', 'Progesterone Status', 'Regional Node Examined',
                                 'Reginol Node Positive', 'Survival Months', 'Status']]
print(cancer_specific)
# Out:
#       Tumor Size Estrogen Status Progesterone Status  Regional Node Examined  \
# 0              4        Positive            Positive                      24
# 1             35        Positive            Positive                      14
# 2             63        Positive            Positive                      14
# 3             18        Positive            Positive                       2
# 4             41        Positive            Positive                       3
# ...          ...             ...                 ...                     ...
# 4019           9        Positive            Positive                       1
# 4020          46        Positive            Positive                      14
# 4021          22        Positive            Negative                      11
# 4022          44        Positive            Positive                      11
# 4023          30        Positive            Positive                       7
#
# ...

# %% [markdown]
# ### Using iloc and loc on the dataset rows

# %%
# selecting the first 200 rows
rows_cancer = df.iloc[0:200] 
print(rows_cancer)
# Out:
#      Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0     68  White        Married       T1      N1       IIA
# 1     50  White        Married       T2      N2      IIIA
# 2     58  White       Divorced       T3      N3      IIIC
# 3     58  White        Married       T1      N1       IIA
# 4     47  White        Married       T2      N1       IIB
# ..   ...    ...            ...      ...     ...       ...
# 195   63  White        Married       T1      N1       IIA
# 196   55  White        Married       T2      N1       IIB
# 197   50  White        Married       T3      N2      IIIA
# 198   52  White        Married       T2      N1       IIB
# 199   47  White        Married       T2      N1       IIB
#
#                  differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0        Poorly differentiated     3  Regional           4        Positive
# 1    Moderately differentiated     2  Regional          35        Positive
# ...

# %%
rows_cancer.index = range(1, len(rows_cancer) + 1)
print(rows_cancer)
# Out:
#      Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 1     68  White        Married       T1      N1       IIA
# 2     50  White        Married       T2      N2      IIIA
# 3     58  White       Divorced       T3      N3      IIIC
# 4     58  White        Married       T1      N1       IIA
# 5     47  White        Married       T2      N1       IIB
# ..   ...    ...            ...      ...     ...       ...
# 196   63  White        Married       T1      N1       IIA
# 197   55  White        Married       T2      N1       IIB
# 198   50  White        Married       T3      N2      IIIA
# 199   52  White        Married       T2      N1       IIB
# 200   47  White        Married       T2      N1       IIB
#
#                  differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 1        Poorly differentiated     3  Regional           4        Positive
# 2    Moderately differentiated     2  Regional          35        Positive
# ...

# %%
selected_rows_ = rows_cancer.loc[0:59]
print(selected_rows_)
# Out:
#     Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 1    68  White        Married       T1      N1       IIA
# 2    50  White        Married       T2      N2      IIIA
# 3    58  White       Divorced       T3      N3      IIIC
# 4    58  White        Married       T1      N1       IIA
# 5    47  White        Married       T2      N1       IIB
# 6    51  White        Single        T1      N1       IIA
# 7    51  White        Married       T1      N1       IIA
# 8    40  White        Married       T2      N1       IIB
# 9    40  White       Divorced       T4      N3      IIIC
# 10   69  White        Married       T4      N3      IIIC
# 11   68  White        Widowed       T1      N1       IIA
# 12   46  White        Married       T3      N1      IIIA
# 13   65  White        Married       T2      N1       IIB
# 14   48  White        Married       T1      N2      IIIA
# 15   62  White       Divorced       T2      N3      IIIC
# ...

# %% [markdown]
# # Data Exploration with Pandas

# %% [markdown]
# #### Data exploration and data cleaning are important steps in the data analysis process.
# ##### Data exploration is the process of analyzing and summarizing the main characteristics of a data set, such as its size, structure, and distribution of values. The goal is to understand the data and identify any potential issues, such as missing values or outliers, that may need to be addressed in the data cleaning process.
# ##### Data cleaning is the process of preparing the data for analysis by removing or correcting any errors, inconsistencies, or missing values. This step is critical as it ensures that the data is accurate, complete, and consistent, which is essential for reliable and meaningful analysis.

# %% [markdown]
# #### Data exploration using pandas

# %%
import pandas as pd

data = pd.read_csv("C:/Users/user/Downloads/Popular_Baby_Names.csv")

# %%
data
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# ...

# %% [markdown]
# ### Data Exploration

# %%
print(data.head())
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49509 entries, 0 to 49508
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year of Birth       49509 non-null  int64
#  1   Gender              49509 non-null  object
#  2   Ethnicity           49509 non-null  object
#  3   Child's First Name  49509 non-null  object
#  4   Count               49509 non-null  int64
#  5   Rank                49509 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 2.3+ MB
# None

# %%
print(data.describe())
# Out:
#        Year of Birth         Count          Rank
# count   49509.000000  49509.000000  49509.000000
# mean     2013.407421     33.839807     57.032418
# std         2.145505     38.877785     25.504754
# min      2011.000000     10.000000      1.000000
# 25%      2012.000000     13.000000     38.000000
# 50%      2013.000000     20.000000     58.000000
# 75%      2014.000000     36.000000     78.000000
# max      2019.000000    426.000000    102.000000

# %%
print(data.describe(include='all'))
# Out:
#         Year of Birth  Gender Ethnicity Child's First Name         Count  \
# count    49509.000000   49509     49509              49509  49509.000000
# unique            NaN       2         7               3211           NaN
# top               NaN  FEMALE  HISPANIC              Avery           NaN
# freq              NaN   25275     14530                100           NaN
# mean      2013.407421     NaN       NaN                NaN     33.839807
# std          2.145505     NaN       NaN                NaN     38.877785
# min       2011.000000     NaN       NaN                NaN     10.000000
# 25%       2012.000000     NaN       NaN                NaN     13.000000
# 50%       2013.000000     NaN       NaN                NaN     20.000000
# 75%       2014.000000     NaN       NaN                NaN     36.000000
# max       2019.000000     NaN       NaN                NaN    426.000000
#
#                 Rank
# count   49509.000000
# unique           NaN
# top              NaN
# ...

# %% [markdown]
# ## Data Wrangling using Pandas

# %%
print(data.isna())

# %%
# Check for missing values
print(data.isnull())
# Out:
#        Year of Birth  Gender  Ethnicity  Child's First Name  Count   Rank
# 0              False   False      False               False  False  False
# 1              False   False      False               False  False  False
# 2              False   False      False               False  False  False
# 3              False   False      False               False  False  False
# 4              False   False      False               False  False  False
# ...              ...     ...        ...                 ...    ...    ...
# 49504          False   False      False               False  False  False
# 49505          False   False      False               False  False  False
# 49506          False   False      False               False  False  False
# 49507          False   False      False               False  False  False
# 49508          False   False      False               False  False  False
#
# [49509 rows x 6 columns]

# %%
data.isna().sum()
# Out:
# Year of Birth         0
# Gender                0
# Ethnicity             0
# Child's First Name    0
# Count                 0
# Rank                  0
# dtype: int64

# %% [markdown]
# ### Dealing with missing values

# %%
import pandas as pd

food = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")

# %%
food
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %%
# inspect the data
print(food.head())
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %%
print(food.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         16 non-null     object
#  1   Real coffee     16 non-null     int64
#  2   Instant coffee  16 non-null     int64
#  3   Tea             16 non-null     int64
#  4   Sweetener       15 non-null     float64
#  5   Biscuits        15 non-null     float64
#  6   Powder soup     16 non-null     int64
#  7   Tin soup        16 non-null     int64
#  8   Potatoes        16 non-null     int64
#  9   Frozen fish     16 non-null     int64
#  10  Frozen veggies  16 non-null     int64
#  11  Apples          16 non-null     int64
#  12  Oranges         16 non-null     int64
#  13  Tinned fruit    16 non-null     int64
#  14  Jam             16 non-null     int64
#  15  Garlic          16 non-null     int64
#  16  Butter          16 non-null     int64
# ...

# %%
# Check for missing values
print(food.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           1
# Crisp bread       0
# dtype: int64

# %% [markdown]
# # 1. Mode
# Replacing missing values with the mode: Mode is the most frequently occurring value in a column. This method is useful when the data is categorical.

# %%
# Replace missing values with mode
# data['column_name'].fillna(data['column_name'].mode()[0], inplace=True)

# %%
# Replace missing values with the mode for specific columns
columns_with_missing_values = ['Sweetener', 'Biscuits', 'Yoghurt']

# %%
for column in columns_with_missing_values:
    mode_value = food[column].mode()[0]
    food[column].fillna(mode_value, inplace=True)

# %%
print(food.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64

# %%
print(food.head())
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %% [markdown]
# ### Handling all the rows dynamically.

# %%
import pandas as pd

food = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")
food
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %%
# Identifying columns with missing values
columns_ = food.columns[food.isnull().any()]

# %%
# Replace missing values with mode for each column with missing values
for column in columns_:
    mode_value = food[column].mode()[0]
    food[column].fillna(mode_value, inplace=True)

# %%
print(food.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64

# %% [markdown]
# # 2. Mean
# Replacing missing values with the mean: Mean is the average value of a column. This method is useful when the data is numerical.

# %%
# data['column_name'].fillna(data['column_name'].mean(), inplace=True)

# %%
import pandas as pd

food = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")
food
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %%
# checking for missing values
print(food.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           1
# Crisp bread       0
# dtype: int64

# %%
# Replace missing values with the mean for specific columns
missing_values = ['Sweetener', 'Biscuits', 'Yoghurt']

# %%
for column in missing_values:
    mean_value = food[column].mean()
    food[column].fillna(mean_value, inplace=True)

# %%
print(food.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64

# %%
print(food.head())
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %% [markdown]
# #### Handling the missing values dynamically

# %%
# Identifying columns with missing values
missing_values = food.columns[food.isnull().any()]

# %%
# Replacing missing values with mean for each column with missing values
for column in missing_values:
    mean_value = food[column].mean()  # Calculate the mean
    food[column].fillna(mean_value, inplace=True)  # Replace missing values with mean

# %%
print(food.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64

# %% [markdown]
# # 3. Median
# Replacing missing values with the median: Median is the middle value of a column when it is sorted in ascending order. This method is useful when the data is numerical and has outliers.

# %%
import pandas as pd

food_ = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")
food_
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %%
# Checking for missing values
print(food_.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           1
# Crisp bread       0
# dtype: int64

# %%
# Replacing missing values with the median for the specific columns
missing_values_ = ['Sweetener', 'Biscuits', 'Yoghurt']

# %%
for column in missing_values_:
    median_value = food_[column].median() 
    food_[column].fillna(median_value, inplace=True)

# %%
print(food_.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64

# %%
print(food_.head())
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %% [markdown]
# ### Handling all columns at once

# %%
import pandas as pd

food_ = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")
food_
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %%
print(food_.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           1
# Crisp bread       0
# dtype: int64

# %%
_missing_values = food_.columns[food.isnull().any()]

for column in _missing_values:
    median_value = food_[column].median()
    food_[column].fillna(median_value, inplace=True)

# %%
print(food.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         0
# Biscuits          0
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           0
# Crisp bread       0
# dtype: int64

# %% [markdown]
# ### An outlier is an observation that lies an abnormal distance from other values in a random sample from a population.

# %% [markdown]
# # Remove NAN
# Use the method that fits your specific use case and data. You should also keep in mind that removing or filling NaN values may have an effect on the analysis results, so choose the method carefully.
#
# It's important to note that these methods can be used depending on the data distribution and the goals of the analysis. Mean and median are more robust to outliers, while mode is more appropriate for categorical data.
#
# To remove NaN (Not a Number) values in Pandas, you can use the following methods:
#
# ### Removes rows with NaN
# df.dropna(axis=0, how='any', inplace=True)
#
# ### Removes columns with NaN
# df.dropna(axis=1, how='any', inplace=True)

# %%
import pandas as pd

food_ = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")
food_
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %%
print(food_.isnull().sum())
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           1
# Crisp bread       0
# dtype: int64

# %%
# Dropping rows with any NaN values
food_.dropna(axis=0, how='any', inplace=True)

# %%
print(food_)
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 11      Denmark           96              17   92       35.0      66.0
# 12       Norway           92              17   83       13.0      62.0
# ...

# %%
food_ = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")
food_
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 3       Holland           96              62   98       32.0      62.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 6       England           27              86   99       22.0      91.0
# 7      Portugal           72              26   77        2.0      22.0
# 8       Austria           55              31   61       15.0      29.0
# 9   Switzerland           73              72   85       25.0      31.0
# 10       Sweden           97              13   93       31.0       NaN
# 11      Denmark           96              17   92       35.0      66.0
# ...

# %%
# Dropping columns with any NaN values
food_.dropna(axis=1, how='any', inplace=True)

# %%
print(food_)
# Out:
#         Country  Real coffee  Instant coffee  Tea  Powder soup  Tin soup  \
# 0       Germany           90              49   88           51        19
# 1         Italy           82              10   60           41         3
# 2        France           88              42   63           53        11
# 3       Holland           96              62   98           67        43
# 4       Belgium           94              38   48           37        23
# 5    Luxembourg           97              61   86           73        12
# 6       England           27              86   99           55        76
# 7      Portugal           72              26   77           34         1
# 8       Austria           55              31   61           33         1
# 9   Switzerland           73              72   85           69        10
# 10       Sweden           97              13   93           43        43
# 11      Denmark           96              17   92           32        17
# ...

# %%
num_columns = food_.shape[1]
print(num_columns)
# Out:
# 18

# %%
num_rows = food_.shape[0]
print(num_rows)
# Out:
# 16

# %% [markdown]
# # Removing outliers and saving the data
# ### An outlier is an observation that lies an abnormal distance from other values in a random sample from a population.

# %% [markdown]
# ## How do we know when a dataset has outliers?
#
# #### You can use various statistical and visualization methods to identify outliers in a dataset. Let's look at some common techniques:

# %% [markdown]
# ### 1. Box Plot
# Box plots are a great way to visualize outliers. Any data point outside the whiskers of the box plot is considered an outlier.

# %%
import seaborn as sns

titanic_df = sns.load_dataset('titanic')
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(titanic_df.describe())
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=titanic_df['age'])
plt.show()

# %% [markdown]
# ### 2. Scatter Plot
# Scatter plots can help you identify outliers in two-dimensional data.

# %%
sns.scatterplot(x='age', y='fare', data=titanic_df)
plt.show()

# %%
food_
# Out:
#         Country  Real coffee  Instant coffee  Tea  Powder soup  Tin soup  \
# 0       Germany           90              49   88           51        19
# 1         Italy           82              10   60           41         3
# 2        France           88              42   63           53        11
# 3       Holland           96              62   98           67        43
# 4       Belgium           94              38   48           37        23
# 5    Luxembourg           97              61   86           73        12
# 6       England           27              86   99           55        76
# 7      Portugal           72              26   77           34         1
# 8       Austria           55              31   61           33         1
# 9   Switzerland           73              72   85           69        10
# 10       Sweden           97              13   93           43        43
# 11      Denmark           96              17   92           32        17
# ...

# %% [markdown]
# ### Let's look at our imported dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
food_ = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")
print(food_.head())
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %%
# Let's look at columns that are numerical
num_columns = food_.select_dtypes(include=['float64', 'int64']).columns

# %%
plt.figure(figsize=(15, 20))  
for i, column in enumerate(num_columns, 1):
    plt.subplot(len(num_columns), 1, i)
    sns.boxplot(data=food_, x=column)
    plt.title(f'Box plot of {column}')
    plt.xticks(rotation=45) 

plt.subplots_adjust(hspace=0.5)  
plt.subplots_adjust(wspace=0.5) 

plt.show()

# %% [markdown]
# # Removing outliers and saving the data in our dataset using z-score

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
food_ = pd.read_csv("C:/Users/user/Downloads/food-consumption.csv")
print(food_.head())
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           67        43         7           14  ...      83       89
# 4           37        23         9           13  ...      76       76
#
#    Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# 0            44   71      22      91         85         74     30.0
# ...

# %%
# calculating Z-scores for each column except "Country"
# np.abs() takes the absolute value of the z-scores.
cols = food_.columns[1:]
z_scores = np.abs(stats.zscore(food_[cols]))

# %%
# Identifying and Removing Outliers
# z-score > 2 for extreme outliers and filtering the dataset
# .any(axis=1) checks each row if it has at least one outlier.
threshold = 2
outliers = (z_scores > threshold).any(axis=1)
cleaned_data = food_[~outliers]

# %%
print(cleaned_data)
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 9   Switzerland           73              72   85       25.0      31.0
# 12       Norway           92              17   83       13.0      62.0
# 13      Finland           98              12   84       20.0      64.0
#
#     Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0            51        19        21           27  ...      81       75
# 1            41         3         2            4  ...      67       71
# 2            53        11        23           11  ...      87       84
# ...

# %%
# Dropping rows with any NaN values
cleaned_data = cleaned_data.dropna(axis=0, how='any')

# %%
cleaned_data
# Out:
#         Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany           90              49   88       19.0      57.0
# 1         Italy           82              10   60        2.0      55.0
# 2        France           88              42   63        4.0      76.0
# 4       Belgium           94              38   48       11.0      74.0
# 5    Luxembourg           97              61   86       28.0      79.0
# 9   Switzerland           73              72   85       25.0      31.0
# 12       Norway           92              17   83       13.0      62.0
#
#     Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0            51        19        21           27  ...      81       75
# 1            41         3         2            4  ...      67       71
# 2            53        11        23           11  ...      87       84
# 4            37        23         9           13  ...      76       76
# ...

# %%
# Boxplot before outlier removal
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.boxplot(food_.iloc[:, 1:].values, labels=food_.columns[1:], vert=False)
plt.title('Before Outlier Removal')
plt.xlabel('Values')
plt.ylabel('Features')


# Boxplot after outlier removal
plt.subplot(1, 2, 2)
plt.boxplot(cleaned_data.iloc[:, 1:].values, labels=cleaned_data.columns[1:], vert=False)
plt.title('After Outlier Removal')
plt.xlabel('Values')
plt.ylabel('Features')

plt.tight_layout()
plt.show()

# %%
# Let's save the cleaned data
cleaned_data.to_csv("cleaned_data.csv", index=False)

# %%
data_cleaned = pd.read_csv("C:/Users/user/Desktop/New folder/Gomycode/cleaned_dataset.csv")
data_cleaned
# Out:
#        Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0      Germany           90              49   88       19.0      57.0
# 1        Italy           82              10   60        2.0      55.0
# 2       France           88              42   63        4.0      76.0
# 3      Belgium           94              38   48       11.0      74.0
# 4   Luxembourg           97              61   86       28.0      79.0
# 5  Switzerland           73              72   85       25.0      31.0
# 6       Norway           92              17   83       13.0      62.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0           51        19        21           27  ...      81       75
# 1           41         3         2            4  ...      67       71
# 2           53        11        23           11  ...      87       84
# 3           37        23         9           13  ...      76       76
# ...

# %% [markdown]
# ## Formatting and transforming data
#
# ##### Formatting column datatype
# data['column_name'] = data['column_name'].astype(str)

# %%
print(cleaned_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 0 to 12
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         7 non-null      object
#  1   Real coffee     7 non-null      int64
#  2   Instant coffee  7 non-null      int64
#  3   Tea             7 non-null      int64
#  4   Sweetener       7 non-null      float64
#  5   Biscuits        7 non-null      float64
#  6   Powder soup     7 non-null      int64
#  7   Tin soup        7 non-null      int64
#  8   Potatoes        7 non-null      int64
#  9   Frozen fish     7 non-null      int64
#  10  Frozen veggies  7 non-null      int64
#  11  Apples          7 non-null      int64
#  12  Oranges         7 non-null      int64
#  13  Tinned fruit    7 non-null      int64
#  14  Jam             7 non-null      int64
#  15  Garlic          7 non-null      int64
#  16  Butter          7 non-null      int64
# ...

# %%
# Formatting column datatype
cleaned_data['Real coffee'] = cleaned_data['Real coffee'].astype(str)

# %%
print(cleaned_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 0 to 12
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         7 non-null      object
#  1   Real coffee     7 non-null      object
#  2   Instant coffee  7 non-null      int64
#  3   Tea             7 non-null      int64
#  4   Sweetener       7 non-null      float64
#  5   Biscuits        7 non-null      float64
#  6   Powder soup     7 non-null      int64
#  7   Tin soup        7 non-null      int64
#  8   Potatoes        7 non-null      int64
#  9   Frozen fish     7 non-null      int64
#  10  Frozen veggies  7 non-null      int64
#  11  Apples          7 non-null      int64
#  12  Oranges         7 non-null      int64
#  13  Tinned fruit    7 non-null      int64
#  14  Jam             7 non-null      int64
#  15  Garlic          7 non-null      int64
#  16  Butter          7 non-null      int64
# ...

# %%
# Applying function to a column
cleaned_data['Country'] = cleaned_data['Country'].apply(lambda x: x.upper())

# %%
cleaned_data
# Out:
#         Country Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       GERMANY          90              49   88       19.0      57.0
# 1         ITALY          82              10   60        2.0      55.0
# 2        FRANCE          88              42   63        4.0      76.0
# 4       BELGIUM          94              38   48       11.0      74.0
# 5    LUXEMBOURG          97              61   86       28.0      79.0
# 9   SWITZERLAND          73              72   85       25.0      31.0
# 12       NORWAY          92              17   83       13.0      62.0
#
#     Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0            51        19        21           27  ...      81       75
# 1            41         3         2            4  ...      67       71
# 2            53        11        23           11  ...      87       84
# 4            37        23         9           13  ...      76       76
# ...

# %%
# reverting back to the original state
cleaned_data['Country'] = cleaned_data['Country'].apply(lambda x: x.title())

# %%
cleaned_data
# Out:
#         Country Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0       Germany          90              49   88       19.0      57.0
# 1         Italy          82              10   60        2.0      55.0
# 2        France          88              42   63        4.0      76.0
# 4       Belgium          94              38   48       11.0      74.0
# 5    Luxembourg          97              61   86       28.0      79.0
# 9   Switzerland          73              72   85       25.0      31.0
# 12       Norway          92              17   83       13.0      62.0
#
#     Powder soup  Tin soup  Potatoes  Frozen fish  ...  Apples  Oranges  \
# 0            51        19        21           27  ...      81       75
# 1            41         3         2            4  ...      67       71
# 2            53        11        23           11  ...      87       84
# 4            37        23         9           13  ...      76       76
# ...

# %%
# Formatting column datatype
cleaned_data['Real coffee'] = cleaned_data['Real coffee'].astype(int)

# %%
print(cleaned_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 0 to 12
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         7 non-null      object
#  1   Real coffee     7 non-null      int32
#  2   Instant coffee  7 non-null      int64
#  3   Tea             7 non-null      int64
#  4   Sweetener       7 non-null      float64
#  5   Biscuits        7 non-null      float64
#  6   Powder soup     7 non-null      int64
#  7   Tin soup        7 non-null      int64
#  8   Potatoes        7 non-null      int64
#  9   Frozen fish     7 non-null      int64
#  10  Frozen veggies  7 non-null      int64
#  11  Apples          7 non-null      int64
#  12  Oranges         7 non-null      int64
#  13  Tinned fruit    7 non-null      int64
#  14  Jam             7 non-null      int64
#  15  Garlic          7 non-null      int64
#  16  Butter          7 non-null      int64
# ...

# %% [markdown]
# ## assign
#
# #### In pandas, the df.assign() function is used to add new columns or alter existing ones in a DataFrame by assigning the result of a computation to a new column. It creates a new DataFrame with the added or updated columns while leaving the previous DataFrame unchanged.

# %% [markdown]
# # Dataset on Covid-19

# %%
url = 'https://raw.githubusercontent.com/datasets/covid-19/main/data/countries-aggregated.csv'
Covid_data = pd.read_csv(url)

# %%
Covid_data
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460
# 161564  2022-04-13     Zimbabwe     247160          0    5460
# 161565  2022-04-14     Zimbabwe     247208          0    5462
# 161566  2022-04-15     Zimbabwe     247237          0    5462
# 161567  2022-04-16     Zimbabwe     247237          0    5462
#
# [161568 rows x 5 columns]

# %%
Covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161568 entries, 0 to 161567
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       161568 non-null  object
#  1   Country    161568 non-null  object
#  2   Confirmed  161568 non-null  int64
#  3   Recovered  161568 non-null  int64
#  4   Deaths     161568 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 6.2+ MB

# %%
Covid_data.describe()
# Out:
#           Confirmed     Recovered         Deaths
# count  1.615680e+05  1.615680e+05  161568.000000
# mean   7.361569e+05  1.453967e+05   13999.436089
# std    3.578884e+06  9.748275e+05   59113.581271
# min    0.000000e+00  0.000000e+00       0.000000
# 25%    1.220000e+03  0.000000e+00      17.000000
# 50%    2.369200e+04  1.260000e+02     365.000000
# 75%    2.558420e+05  1.797225e+04    4509.000000
# max    8.062512e+07  3.097475e+07  988609.000000

# %%
Covid_data.isna().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
# Let's look at the ASSIGN function
Covid_new = Covid_data.assign(Survivors = Covid_data['Deaths'] - Covid_data['Confirmed'])

print(Covid_new)
# Out:
#               Date      Country  Confirmed  Recovered  Deaths  Survivors
# 0       2020-01-22  Afghanistan          0          0       0          0
# 1       2020-01-23  Afghanistan          0          0       0          0
# 2       2020-01-24  Afghanistan          0          0       0          0
# 3       2020-01-25  Afghanistan          0          0       0          0
# 4       2020-01-26  Afghanistan          0          0       0          0
# ...            ...          ...        ...        ...     ...        ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460    -241634
# 161564  2022-04-13     Zimbabwe     247160          0    5460    -241700
# 161565  2022-04-14     Zimbabwe     247208          0    5462    -241746
# 161566  2022-04-15     Zimbabwe     247237          0    5462    -241775
# 161567  2022-04-16     Zimbabwe     247237          0    5462    -241775
#
# [161568 rows x 6 columns]

# %%
Covid_new = Covid_new.assign(Water = Covid_new['Survivors'])
Covid_new
# Out:
#               Date      Country  Confirmed  Recovered  Deaths  Survivors  \
# 0       2020-01-22  Afghanistan          0          0       0          0
# 1       2020-01-23  Afghanistan          0          0       0          0
# 2       2020-01-24  Afghanistan          0          0       0          0
# 3       2020-01-25  Afghanistan          0          0       0          0
# 4       2020-01-26  Afghanistan          0          0       0          0
# ...            ...          ...        ...        ...     ...        ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460    -241634
# 161564  2022-04-13     Zimbabwe     247160          0    5460    -241700
# 161565  2022-04-14     Zimbabwe     247208          0    5462    -241746
# 161566  2022-04-15     Zimbabwe     247237          0    5462    -241775
# 161567  2022-04-16     Zimbabwe     247237          0    5462    -241775
#
#          Water
# 0            0
# 1            0
# 2            0
# 3            0
# ...

# %% [markdown]
# ## query

# %% [markdown]
# ##### Pandas' df.query() function allows you to filter data from a DataFrame using a query phrase. Similar to SQL queries, it allows you to easily choose portions of data that fulfil specific criteria.

# %%
Afgh = Covid_data.query('Country == "Afghanistan"')

# %%
Afgh
# Out:
#            Date      Country  Confirmed  Recovered  Deaths
# 0    2020-01-22  Afghanistan          0          0       0
# 1    2020-01-23  Afghanistan          0          0       0
# 2    2020-01-24  Afghanistan          0          0       0
# 3    2020-01-25  Afghanistan          0          0       0
# 4    2020-01-26  Afghanistan          0          0       0
# ..          ...          ...        ...        ...     ...
# 811  2022-04-12  Afghanistan     178257          0    7676
# 812  2022-04-13  Afghanistan     178295          0    7676
# 813  2022-04-14  Afghanistan     178352          0    7676
# 814  2022-04-15  Afghanistan     178373          0    7676
# 815  2022-04-16  Afghanistan     178387          0    7676
#
# [816 rows x 5 columns]

# %%
Afgh_deaths = Covid_data.query('Country == "Afghanistan" and Deaths > 1000')
Afgh_deaths
# Out:
#            Date      Country  Confirmed  Recovered  Deaths
# 172  2020-07-12  Afghanistan      34537      21216    1014
# 173  2020-07-13  Afghanistan      34541      21254    1016
# 174  2020-07-14  Afghanistan      34826      21454    1049
# 175  2020-07-15  Afghanistan      35026      22456    1098
# 176  2020-07-16  Afghanistan      35156      22824    1117
# ..          ...          ...        ...        ...     ...
# 811  2022-04-12  Afghanistan     178257          0    7676
# 812  2022-04-13  Afghanistan     178295          0    7676
# 813  2022-04-14  Afghanistan     178352          0    7676
# 814  2022-04-15  Afghanistan     178373          0    7676
# 815  2022-04-16  Afghanistan     178387          0    7676
#
# [644 rows x 5 columns]

# %%
Afgh_data= Covid_data.query('Country == "Afghanistan" and Confirmed > 1000 and Recovered < 100')
Afgh_data
# Out:
#            Date      Country  Confirmed  Recovered  Deaths
# 561  2021-08-05  Afghanistan     149361          0    6864
# 562  2021-08-06  Afghanistan     149810          0    6879
# 563  2021-08-07  Afghanistan     150240          0    6897
# 564  2021-08-08  Afghanistan     150458          0    6908
# 565  2021-08-09  Afghanistan     150778          0    6936
# ..          ...          ...        ...        ...     ...
# 811  2022-04-12  Afghanistan     178257          0    7676
# 812  2022-04-13  Afghanistan     178295          0    7676
# 813  2022-04-14  Afghanistan     178352          0    7676
# 814  2022-04-15  Afghanistan     178373          0    7676
# 815  2022-04-16  Afghanistan     178387          0    7676
#
# [255 rows x 5 columns]

# %% [markdown]
# ## sort_values
#
# #### Pandas' sort_values function is used to sort a DataFrame by one or more columns. You may sort the values ascending or descending, and you can sort by numerous columns, each with its own sorting order.

# %%
import pandas as pd

data = pd.read_csv("C:/Users/user/Downloads/Popular_Baby_Names.csv")
data
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# ...

# %%
# sorting by a single column
# sorting by year in descending order
sorted_data = data.sort_values(by='Year of Birth', ascending=False)
print(sorted_data)
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 38501           2019    MALE          WHITE NON HISPANIC               Leon
# 38849           2019  FEMALE          WHITE NON HISPANIC              Chava
# 38847           2019  FEMALE          WHITE NON HISPANIC               Toby
# 38846           2019  FEMALE          WHITE NON HISPANIC               Luna
# 38845           2019  FEMALE          WHITE NON HISPANIC           Juliette
# ...              ...     ...                         ...                ...
# 39655           2011    MALE  ASIAN AND PACIFIC ISLANDER            MOHAMED
# 39656           2011    MALE  ASIAN AND PACIFIC ISLANDER           MOHAMMAD
# 39657           2011    MALE  ASIAN AND PACIFIC ISLANDER           MOHAMMED
# 39658           2011    MALE  ASIAN AND PACIFIC ISLANDER           MUHAMMAD
# 0               2011  FEMALE                    HISPANIC          GERALDINE
#
#        Count  Rank
# 38501     40    67
# ...

# %%
# sorting by 'count' in ascending order
sorted_data = data.sort_values(by='Count')
print(sorted_data)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
# 25037           2017    MALE            HISPANIC              Byron     10
# 25038           2017    MALE            HISPANIC             Camilo     10
# 25039           2017    MALE            HISPANIC            Carmelo     10
# 25040           2017    MALE            HISPANIC             Damien     10
# ...              ...     ...                 ...                ...    ...
# 37557           2019    MALE            HISPANIC               Liam    423
# 3447            2011    MALE            HISPANIC             JAYDEN    426
# 26907           2011    MALE            HISPANIC             JAYDEN    426
# 40996           2011    MALE            HISPANIC             JAYDEN    426
# 17403           2011    MALE            HISPANIC             JAYDEN    426
#
#        Rank
# 49508    40
# 25037    89
# 25038    89
# 25039    89
# ...

# %%
# Sorting by 'Year of Birth' in ascending order and 'Rank' in descending order
sorted_data = data.sort_values(by=['Year of Birth', 'Rank'], ascending=[True, False])
print(sorted_data)
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 1678            2011    MALE          WHITE NON HISPANIC             ASHTON
# 1680            2011    MALE          WHITE NON HISPANIC           AUGUSTUS
# 1686            2011    MALE          WHITE NON HISPANIC              AYDEN
# 1691            2011    MALE          WHITE NON HISPANIC            BENNETT
# 1693            2011    MALE          WHITE NON HISPANIC             BERISH
# ...              ...     ...                         ...                ...
# 38250           2019  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 38407           2019    MALE          WHITE NON HISPANIC              David
# 38769           2019  FEMALE          WHITE NON HISPANIC              Chaya
# 39152           2019    MALE          BLACK NON HISPANIC               Noah
# 39320           2019  FEMALE          BLACK NON HISPANIC                Ava
#
#        Count  Rank
# 1678      10    97
# ...

# %% [markdown]
# ## sample()
#
# #### In Pandas, the df.sample() function selects rows (or columns) at random from a DataFrame. This is handy for generating a smaller representative sample from a bigger dataset.

# %%
# let's select a Random Sample of Rows
## A sample of 3 Random Rows
baby_3rows = data.sample(n=3)
print(baby_3rows)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 37506           2014    MALE  WHITE NON HISPANIC             Shlomo     55
# 4754            2012  FEMALE      WHITE NON HISP             GIULIA     12
# 3010            2011  FEMALE            HISPANIC              NOEMI     11
#
#        Rank
# 37506    59
# 4754     81
# 3010     77

# %%
# Let's have a sample with 30% of the Rows
baby_30 = data.sample(frac=0.3)
print(baby_30)
# Out:
#        Year of Birth  Gender                   Ethnicity Child's First Name  \
# 46067           2014  FEMALE                    HISPANIC               Kate
# 21699           2013    MALE          WHITE NON HISPANIC               Luca
# 33545           2016    MALE  ASIAN AND PACIFIC ISLANDER              Hamza
# 48864           2018  FEMALE          WHITE NON HISPANIC              Fiona
# 24283           2017  FEMALE          WHITE NON HISPANIC              Julie
# ...              ...     ...                         ...                ...
# 16511           2011  FEMALE          BLACK NON HISPANIC            ARIANNA
# 42464           2012  FEMALE              WHITE NON HISP           VIRGINIA
# 34365           2013  FEMALE          WHITE NON HISPANIC            Lillian
# 41133           2011    MALE                    HISPANIC              YAHIR
# 24187           2017  FEMALE          WHITE NON HISPANIC          Francesca
#
#        Count  Rank
# 46067     10    73
# ...

# %%
# Let's select a random sample of columns
# A sample of 2 random columns
baby_cols = data.sample(n=2, axis=1)
print(baby_cols)
# Out:
#        Year of Birth  Count
# 0               2011     13
# 1               2011     21
# 2               2011     49
# 3               2011     38
# 4               2011     36
# ...              ...    ...
# 49504           2018     10
# 49505           2018     10
# 49506           2018     10
# 49507           2018     10
# 49508           2018     10
#
# [49509 rows x 2 columns]

# %% [markdown]
# #### fillna()

# %%
Covid_data
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460
# 161564  2022-04-13     Zimbabwe     247160          0    5460
# 161565  2022-04-14     Zimbabwe     247208          0    5462
# 161566  2022-04-15     Zimbabwe     247237          0    5462
# 161567  2022-04-16     Zimbabwe     247237          0    5462
#
# [161568 rows x 5 columns]

# %%
Covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161568 entries, 0 to 161567
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       161568 non-null  object
#  1   Country    161568 non-null  object
#  2   Confirmed  161568 non-null  int64
#  3   Recovered  161568 non-null  int64
#  4   Deaths     161568 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 6.2+ MB

# %%
Covid_data.isnull().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
# Filling all NaN values with a specific value
Covid_data = Covid_data.fillna(0)
print(Covid_data)
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460
# 161564  2022-04-13     Zimbabwe     247160          0    5460
# 161565  2022-04-14     Zimbabwe     247208          0    5462
# 161566  2022-04-15     Zimbabwe     247237          0    5462
# 161567  2022-04-16     Zimbabwe     247237          0    5462
#
# [161568 rows x 5 columns]

# %% [markdown]
# ## drop()
# #### In Pandas, you may delete rows or columns from a DataFrame using the df.drop() function. You can drop certain rows or columns based on their labels or indexes.

# %%
data
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 0               2011  FEMALE            HISPANIC          GERALDINE     13
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# ...              ...     ...                 ...                ...    ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 0        75
# 1        67
# 2        42
# 3        51
# ...

# %%
# Dropping a single column
drop_ = data.drop(columns=['Count'])
print(drop_)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Rank
# 0               2011  FEMALE            HISPANIC          GERALDINE    75
# 1               2011  FEMALE            HISPANIC                GIA    67
# 2               2011  FEMALE            HISPANIC             GIANNA    42
# 3               2011  FEMALE            HISPANIC            GISELLE    51
# 4               2011  FEMALE            HISPANIC              GRACE    53
# ...              ...     ...                 ...                ...   ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala    40
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty    40
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah    40
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone    40
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra    40
#
# [49509 rows x 5 columns]

# %%
# Dropping multiple columns
dropped_col = data.drop(columns=['Count', 'Rank'])
print(dropped_col)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name
# 0               2011  FEMALE            HISPANIC          GERALDINE
# 1               2011  FEMALE            HISPANIC                GIA
# 2               2011  FEMALE            HISPANIC             GIANNA
# 3               2011  FEMALE            HISPANIC            GISELLE
# 4               2011  FEMALE            HISPANIC              GRACE
# ...              ...     ...                 ...                ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra
#
# [49509 rows x 4 columns]

# %%
# Dropping a single row by index
dropped_row = data.drop(index=0)
print(dropped_row)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 1               2011  FEMALE            HISPANIC                GIA     21
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# 5               2011  FEMALE            HISPANIC          GUADALUPE     26
# ...              ...     ...                 ...                ...    ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 1        67
# 2        42
# 3        51
# 4        53
# ...

# %%
# Dropping multiple rows by index
dropped_rows = data.drop(index=[0, 1])
print(dropped_rows)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# 5               2011  FEMALE            HISPANIC          GUADALUPE     26
# 6               2011  FEMALE            HISPANIC             HAILEY    126
# ...              ...     ...                 ...                ...    ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 2        42
# 3        51
# 4        53
# 5        62
# ...

# %%
# Dropping columns using axis parameter
dropped_axis = data.drop(['Count', 'Rank'], axis=1)
print(dropped_axis)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name
# 0               2011  FEMALE            HISPANIC          GERALDINE
# 1               2011  FEMALE            HISPANIC                GIA
# 2               2011  FEMALE            HISPANIC             GIANNA
# 3               2011  FEMALE            HISPANIC            GISELLE
# 4               2011  FEMALE            HISPANIC              GRACE
# ...              ...     ...                 ...                ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra
#
# [49509 rows x 4 columns]

# %%
# Dropping rows using axis parameter
dropped_ = data.drop([0, 1], axis=0)
print(dropped_)
# Out:
#        Year of Birth  Gender           Ethnicity Child's First Name  Count  \
# 2               2011  FEMALE            HISPANIC             GIANNA     49
# 3               2011  FEMALE            HISPANIC            GISELLE     38
# 4               2011  FEMALE            HISPANIC              GRACE     36
# 5               2011  FEMALE            HISPANIC          GUADALUPE     26
# 6               2011  FEMALE            HISPANIC             HAILEY    126
# ...              ...     ...                 ...                ...    ...
# 49504           2018  FEMALE  BLACK NON HISPANIC               Nala     10
# 49505           2018  FEMALE  BLACK NON HISPANIC            Royalty     10
# 49506           2018  FEMALE  BLACK NON HISPANIC            Sariyah     10
# 49507           2018  FEMALE  BLACK NON HISPANIC             Simone     10
# 49508           2018  FEMALE  BLACK NON HISPANIC              Zahra     10
#
#        Rank
# 2        42
# 3        51
# 4        53
# 5        62
# ...

# %% [markdown]
# ## groupby()

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/datasets/covid-19/main/data/countries-aggregated.csv'
Covid_data = pd.read_csv(url)

# %%
Covid_data
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460
# 161564  2022-04-13     Zimbabwe     247160          0    5460
# 161565  2022-04-14     Zimbabwe     247208          0    5462
# 161566  2022-04-15     Zimbabwe     247237          0    5462
# 161567  2022-04-16     Zimbabwe     247237          0    5462
#
# [161568 rows x 5 columns]

# %%
# let's group the number of Confirmed cases, Recovered, and Death cases by country
Country_cases = Covid_data.groupby('Country').sum()

print(Country_cases.head())
# Out:
#                                                           Date  Confirmed  \
# Country
# Afghanistan  2020-01-222020-01-232020-01-242020-01-252020-0...   66031705
# Albania      2020-01-222020-01-232020-01-242020-01-252020-0...   82385140
# Algeria      2020-01-222020-01-232020-01-242020-01-252020-0...   94695072
# Andorra      2020-01-222020-01-232020-01-242020-01-252020-0...    9598486
# Angola       2020-01-222020-01-232020-01-242020-01-252020-0...   26425596
#
#              Recovered   Deaths
# Country
# Afghanistan   18289880  2874099
# Albania       22652652  1320658
# Algeria       25670233  2651996
# Andorra        3085649    75889
# Angola         5895800   605294

# %% [markdown]
# ## transpose()

# %%
Covid_data
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460
# 161564  2022-04-13     Zimbabwe     247160          0    5460
# 161565  2022-04-14     Zimbabwe     247208          0    5462
# 161566  2022-04-15     Zimbabwe     247237          0    5462
# 161567  2022-04-16     Zimbabwe     247237          0    5462
#
# [161568 rows x 5 columns]

# %%
# Transposing the data
transposed_ = Covid_data.transpose()

# %%
print(transposed_)
# Out:
#                 0            1            2            3            4       \
# Date        2020-01-22   2020-01-23   2020-01-24   2020-01-25   2020-01-26
# Country    Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# Confirmed            0            0            0            0            0
# Recovered            0            0            0            0            0
# Deaths               0            0            0            0            0
#
#                 5            6            7            8            9       \
# Date        2020-01-27   2020-01-28   2020-01-29   2020-01-30   2020-01-31
# Country    Afghanistan  Afghanistan  Afghanistan  Afghanistan  Afghanistan
# Confirmed            0            0            0            0            0
# Recovered            0            0            0            0            0
# Deaths               0            0            0            0            0
#
# ...

# %% [markdown]
# ## merge()

# %%
Covid_data
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460
# 161564  2022-04-13     Zimbabwe     247160          0    5460
# 161565  2022-04-14     Zimbabwe     247208          0    5462
# 161566  2022-04-15     Zimbabwe     247237          0    5462
# 161567  2022-04-16     Zimbabwe     247237          0    5462
#
# [161568 rows x 5 columns]

# %%
population_data = {
    'Country': ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola'],
    'Population': [38928341, 2877797, 43851044, 77265, 32866272]
}
population_df = pd.DataFrame(population_data)

# %%
# Merging the COVID-19 data with the population data on the 'Country' column
merged = pd.merge(Covid_data, population_df, on='Country', how='inner')

# %%
merged
# Out:
#             Date      Country  Confirmed  Recovered  Deaths  Population
# 0     2020-01-22  Afghanistan          0          0       0    38928341
# 1     2020-01-23  Afghanistan          0          0       0    38928341
# 2     2020-01-24  Afghanistan          0          0       0    38928341
# 3     2020-01-25  Afghanistan          0          0       0    38928341
# 4     2020-01-26  Afghanistan          0          0       0    38928341
# ...          ...          ...        ...        ...     ...         ...
# 4075  2022-04-12       Angola      99194          0    1900    32866272
# 4076  2022-04-13       Angola      99194          0    1900    32866272
# 4077  2022-04-14       Angola      99194          0    1900    32866272
# 4078  2022-04-15       Angola      99194          0    1900    32866272
# 4079  2022-04-16       Angola      99194          0    1900    32866272
#
# [4080 rows x 6 columns]

# %% [markdown]
# ## rename()

# %%
Covid_data
# Out:
#               Date      Country  Confirmed  Recovered  Deaths
# 0       2020-01-22  Afghanistan          0          0       0
# 1       2020-01-23  Afghanistan          0          0       0
# 2       2020-01-24  Afghanistan          0          0       0
# 3       2020-01-25  Afghanistan          0          0       0
# 4       2020-01-26  Afghanistan          0          0       0
# ...            ...          ...        ...        ...     ...
# 161563  2022-04-12     Zimbabwe     247094          0    5460
# 161564  2022-04-13     Zimbabwe     247160          0    5460
# 161565  2022-04-14     Zimbabwe     247208          0    5462
# 161566  2022-04-15     Zimbabwe     247237          0    5462
# 161567  2022-04-16     Zimbabwe     247237          0    5462
#
# [161568 rows x 5 columns]

# %%
print(Covid_data.columns)
# Out:
# Index(['Date', 'Country', 'Confirmed', 'Recovered', 'Deaths'], dtype='object')

# %%
# Renaming the columns
Covid_data_renamed = Covid_data.rename(columns={
    'Date': 'Report_Date',
    'Country': 'Country_Name',
    'Confirmed': 'Total_Confirmed',
    'Recovered': 'Total_Recovered',
    'Deaths': 'Total_Deaths'
 })

# %%
print(Covid_data_renamed.columns)
# Out:
# Index(['Report_Date', 'Country_Name', 'Total_Confirmed', 'Total_Recovered',
#        'Total_Deaths'],
#       dtype='object')

# %% [markdown]
# ### Programming puzzle. :
#
# The Tanzanian tourism sector plays a significant role in the Tanzanian economy, contributing about 17% to the country’s GDP and 25% of all foreign exchange revenues. The sector, which provides direct employment for more than 600,000 people and up to 2 million people indirectly, generated approximately $2.4 billion in 2018 according to government statistics. Tanzania received a record 1.1 million international visitor arrivals in 2014, mostly from Europe, the US and Africa.
#
#
#
# #### Objective
#
# Your mission is to pre-process and prepare the provided dataset with the aim of developing a machine learning model to predict what a tourist will spend when visiting Tanzania ( you are not required to build the ML yet)
#
# #### Dataset description
#
# The dataset describes 6476 rows of up-to-date information on tourist expenditure collected by the National Bureau of Statistics (NBS) in Tanzania.The dataset was collected to gain a better understanding of the status of the tourism sector and provide an instrument that will enable sector growth.
# Dataset file
# Dataset description file
#
# #### Instructions:
#
# #### Data cleaning:
#
# 1.Identify the columns containing missing values.
#
# 2.Apply a method to handle the missing values
#
# 3.Check for duplicates and remove if any.
#
# 4.Remove any irrelevant columns.
#
#
# #### Data exploration:
#
# 1.Calculate summary statistics for numerical columns (mean, median, mode, etc).
#
# 2.Find the correlation between columns and create a heatmap.
#
# 3.Find the 3 most frequent countries that visitors tend to come from.
#
# 4.Determine the most common purpose of the visit by 'age_group'.
#
# 5.Analyse the data distribution of 'total_cost' column with respect to sevreal criteria : Country, age_group, purpose Country, age_group, purpose
